# %%
import pickle as pk

# %%
with open ('data/alarm_index_list.pk', 'rb') as f:
    data1 = pk.load(f)

# %% [markdown]
# # 将数据转换成tensor形式
# 总共有17种告警

# %%
# Out:
# [5,
#  5,
#  5,
#  5,
#  5,
#  4,
#  5,
#  5,
#  5,
#  5,
#  5,
#  5,
#  5,
#  4,
#  5,
#  5,
#  4,
#  5,
#  5,
#  5,
#  4,
#  4,
#  4,
#  4,
#  4,
#  5,
#  5,
#  4,
#  4,
#  5,
#  4,
#  5,
#  4,
#  5,
#  3,
#  5,
#  5,
#  5,
#  5,
#  5,
#  5,
#  4,
#  4,
#  3,
#  5,
#  5,
#  4,
#  4,
#  5,
#  5,
#  5,
#  4,
#  5,
#  5,
#  4,
#  9,
#  9,
#  0,
#  0,
#  5,
#  0,
#  5,
#  5,
#  5,
#  3,
#  3,
#  5,
#  3,
#  5,
#  3,
#  4,
#  4,
#  5,
#  4,
#  5,
#  3,
#  5,
#  4,
#  3,
#  5,
#  4,
#  4,
#  4,
#  4,
#  4,
#  3,
#  4,
#  4,
#  4,
#  5,
#  3,
#  4,
#  4,
#  15,
#  3,
#  15,
#  15,
#  15,
#  4,
#  15,
#  15,
#  4,
#  15,
#  15,
#  4,
#  4,
#  15,
#  4,
#  3,
#  15,
#  4,
#  5,
#  3,
#  15,
#  3,
#  3,
#  4,
#  4,
#  3,
#  15,
#  3,
#  4,
#  15,
#  3,
#  15,
#  3,
#  3,
#  3,
#  4,
#  15,
#  15,
#  15,
#  15,
#  4,
#  3,
#  15,
#  3,
#  4,
#  15,
#  3,
#  15,
#  15,
#  4,
#  15,
#  3,
#  15,
#  4,
#  15,
#  3,
#  3,
#  3,
#  15,
#  15,
#  4,
#  3,
#  4,
#  3,
#  3,
#  15,
#  15,
#  15,
#  5,
#  15,
#  4,
#  3,
#  3,
#  3,
#  15,
#  4,
#  3,
#  15,
#  15,
#  15,
#  15,
#  15,
#  6,
#  6,
#  6,
#  6,
#  6,
#  15,
#  6,
#  4,
#  3,
#  15,
#  3,
#  3,
#  15,
#  15,
#  3,
#  3,
#  3,
#  15,
#  4,
#  15,
#  15,
#  15,
#  15,
#  4,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  3,
#  15,
#  15,
#  15,
#  3,
#  15,
#  3,
#  15,
#  15,
#  15,
#  3,
#  15,
#  3,
#  15,
#  3,
#  15,
#  4,
#  3,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  4,
#  15,
#  4,
#  3,
#  15,
#  15,
#  3,
#  4,
#  3,
#  3,
#  15,
#  3,
#  3,
#  15,
#  3,
#  15,
#  15,
#  3,
#  3,
#  3,
#  15,
#  3,
#  3,
#  4,
#  3,
#  3,
#  15,
#  3,
#  3,
#  15,
#  3,
#  15,
#  4,
#  3,
#  3,
#  3,
#  3,
#  15,
#  15,
#  15,
#  3,
#  15,
#  15,
#  3,
#  15,
#  3,
#  15,
#  4,
#  5,
#  15,
#  15,
#  15,
#  3,
#  15,
#  15,
#  5,
#  15,
#  15,
#  4,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  3,
#  15,
#  3,
#  4,
#  3,
#  3,
#  15,
#  3,
#  15,
#  15,
#  15,
#  15,
#  3,
#  4,
#  15,
#  15,
#  3,
#  15,
#  4,
#  15,
#  3,
#  15,
#  3,
#  15,
#  15,
#  15,
#  15,
#  15,
#  4,
#  15,
#  3,
#  15,
#  15,
#  3,
#  15,
#  15,
#  4,
#  15,
#  3,
#  3,
#  3,
#  15,
#  3,
#  4,
#  15,
#  15,
#  15,
#  15,
#  3,
#  15,
#  3,
#  3,
#  15,
#  3,
#  3,
#  3,
#  3,
#  15,
#  15,
#  3,
#  4,
#  3,
#  2,
#  3,
#  4,
#  15,
#  15,
#  15,
#  15,
#  4,
#  15,
#  3,
#  5,
#  3,
#  15,
#  15,
#  3,
#  15,
#  3,
#  3,
#  4,
#  15,
#  3,
#  15,
#  3,
#  4,
#  4,
#  15,
#  15,
#  15,
#  15,
#  15,
#  4,
#  3,
#  4,
#  4,
#  4,
#  3,
#  15,
#  15,
#  4,
#  4,
#  15,
#  3,
#  15,
#  4,
#  3,
#  3,
#  5,
#  3,
#  15,
#  3,
#  15,
#  5,
#  15,
#  15,
#  3,
#  4,
#  15,
#  15,
#  3,
#  15,
#  15,
#  3,
#  3,
#  15,
#  15,
#  3,
#  15,
#  4,
#  15,
#  3,
#  15,
#  3,
#  3,
#  4,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  4,
#  15,
#  15,
#  15,
#  4,
#  15,
#  4,
#  3,
#  15,
#  15,
#  15,
#  15,
#  4,
#  15,
#  15,
#  3,
#  3,
#  4,
#  4,
#  15,
#  15,
#  15,
#  4,
#  15,
#  3,
#  15,
#  3,
#  15,
#  4,
#  15,
#  3,
#  15,
#  15,
#  3,
#  15,
#  2,
#  15,
#  15,
#  3,
#  3,
#  15,
#  3,
#  15,
#  3,
#  4,
#  3,
#  3,
#  3,
#  3,
#  4,
#  15,
#  15,
#  3,
#  3,
#  15,
#  4,
#  15,
#  15,
#  3,
#  15,
#  3,
#  15,
#  4,
#  15,
#  15,
#  15,
#  4,
#  15,
#  3,
#  15,
#  4,
#  15,
#  15,
#  4,
#  15,
#  3,
#  15,
#  15,
#  4,
#  15,
#  4,
#  15,
#  4,
#  15,
#  15,
#  3,
#  3,
#  4,
#  4,
#  4,
#  3,
#  15,
#  15,
#  15,
#  15,
#  15,
#  5,
#  15,
#  15,
#  15,
#  15,
#  15,
#  4,
#  15,
#  15,
#  15,
#  15,
#  15,
#  3,
#  15,
#  3,
#  3,
#  15,
#  4,
#  15,
#  15,
#  15,
#  15,
#  15,
#  3,
#  15,
#  3,
#  15,
#  15,
#  15,
#  15,
#  15,
#  4,
#  3,
#  3,
#  15,
#  15,
#  3,
#  15,
#  3,
#  3,
#  4,
#  15,
#  3,
#  3,
#  15,
#  15,
#  3,
#  15,
#  15,
#  15,
#  15,
#  3,
#  15,
#  4,
#  3,
#  15,
#  3,
#  15,
#  3,
#  3,
#  3,
#  3,
#  15,
#  15,
#  3,
#  3,
#  15,
#  15,
#  3,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  3,
#  15,
#  3,
#  3,
#  15,
#  4,
#  3,
#  15,
#  3,
#  3,
#  15,
#  3,
#  3,
#  3,
#  3,
#  15,
#  4,
#  15,
#  15,
#  3,
#  3,
#  15,
#  15,
#  15,
#  3,
#  3,
#  3,
#  15,
#  3,
#  4,
#  3,
#  5,
#  3,
#  3,
#  15,
#  3,
#  15,
#  15,
#  15,
#  15,
#  4,
#  15,
#  15,
#  3,
#  3,
#  4,
#  15,
#  4,
#  4,
#  15,
#  3,
#  15,
#  3,
#  15,
#  4,
#  3,
#  15,
#  3,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  3,
#  15,
#  15,
#  3,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  4,
#  4,
#  15,
#  15,
#  15,
#  3,
#  4,
#  15,
#  15,
#  15,
#  15,
#  4,
#  3,
#  15,
#  4,
#  4,
#  11,
#  11,
#  15,
#  4,
#  4,
#  4,
#  15,
#  15,
#  3,
#  15,
#  4,
#  3,
#  3,
#  15,
#  3,
#  15,
#  4,
#  15,
#  15,
#  15,
#  3,
#  15,
#  3,
#  3,
#  4,
#  3,
#  15,
#  4,
#  3,
#  15,
#  4,
#  15,
#  3,
#  4,
#  3,
#  3,
#  4,
#  3,
#  4,
#  3,
#  3,
#  3,
#  15,
#  3,
#  3,
#  3,
#  15,
#  3,
#  3,
#  15,
#  15,
#  3,
#  3,
#  5,
#  3,
#  3,
#  3,
#  15,
#  4,
#  15,
#  15,
#  4,
#  15,
#  15,
#  4,
#  15,
#  3,
#  15,
#  15,
#  15,
#  3,
#  15,
#  4,
#  3,
#  4,
#  15,
#  15,
#  15,
#  4,
#  15,
#  3,
#  15,
#  4,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  4,
#  15,
#  15,
#  15,
#  15,
#  4,
#  4,
#  4,
#  15,
#  3,
#  4,
#  3,
#  3,
#  3,
#  3,
#  15,
#  3,
#  4,
#  15,
#  3,
#  3,
#  3,
#  3,
#  15,
#  15,
#  3,
#  15,
#  3,
#  3,
#  15,
#  15,
#  4,
#  15,
#  15,
#  4,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  4,
#  15,
#  4,
#  15,
#  3,
#  15,
#  15,
#  15,
#  15,
#  3,
#  4,
#  15,
#  3,
#  3,
#  3,
#  3,
#  15,
#  15,
#  3,
#  15,
#  15,
#  3,
#  5,
#  15,
#  15,
#  4,
#  15,
#  15,
#  15,
#  15,
#  15,
#  3,
#  15,
#  15,
#  4,
#  3,
#  15,
#  15,
#  15,
#  15,
#  3,
#  4,
#  15,
#  4,
#  15,
#  15,
#  15,
#  4,
#  15,
#  15,
#  15,
#  15,
#  15,
#  5,
#  15,
#  4,
#  15,
#  15,
#  15,
#  15,
#  4,
#  15,
#  15,
#  15,
#  3,
#  15,
#  15,
#  3,
#  3,
#  4,
#  15,
#  15,
#  15,
#  3,
#  15,
#  15,
#  4,
#  4,
#  15,
#  15,
#  4,
#  4,
#  15,
#  15,
#  4,
#  15,
#  15,
#  4,
#  3,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  15,
#  4,
#  15,
#  4,
#  15,
#  4,
#  4,
#  4,
#  3,
#  3,
#  15,
#  5,
#  3,
#  15,
#  15,
#  15,
#  15,
#  4,
#  15,
#  4,
#  3,
#  15,
#  4,
#  3,
#  15,
#  15,
#  3,
#  15,
#  15,
#  3,
#  15,
#  15,
#  15,
#  15,
#  4,
#  15,
#  15,
#  15,
#  2,
#  4,
#  15,
#  15,
#  15,
#  15,
#  3,
#  15,
#  15,
#  15,
#  4,
#  15,
#  15,
#  15,
#  4,
#  15,
#  4,
#  3,
#  3,
#  15,
#  4,
#  3,
#  ...]

# %%
max(data1),min(data1)
# Out:
# (16, 0)

# %%
import torch

# %%
torch.randn(4,5)
# Out:
# tensor([[-0.4533,  0.8564,  2.1331, -0.7756,  0.3580],
#         [-0.4728,  0.5661, -0.4755, -0.3580, -0.7691],
#         [ 0.2861,  0.2088, -0.8266,  0.8213, -0.5762],
#         [-1.3696, -1.4482,  0.0257,  1.0697, -0.3883]])

# %%
for ei in range(input_length):
    encoder_output, encoder_hidden = encoder(
        input_tensor[ei],
        encoder_hidden
    )
    encoder_outputs[ei] = encoder_output[0, 0]
    
decoder_input = torch.tensor([[S_S_token]], device=device)
decoder_hidden = encoder_hidden
